# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv(r"E:\Projects\E-Commerce Revenue Optimization Engine\Data\raw\synthetic_ecommerce_sales_2025.csv")
df
# Out:
#        order_id                           customer_id product_category  \
# 0             1  bdd640fb-0667-4ad1-9c80-317fa3b1799d           Beauty
# 1             2  23b8c1e9-3924-46de-beb1-3b9046685257          Fashion
# 2             3  bd9c66b3-ad3c-4d6d-9a3d-1fa7bc8960a9           Beauty
# 3             4  972a8469-1641-4f82-8b9d-2434e465e150      Electronics
# 4             5  17fc695a-07a0-4a6e-8822-e8f36c031199          Fashion
# ...         ...                                   ...              ...
# 99995     99996  95898eb0-3712-4824-accb-8d40fab73167           Beauty
# 99996     99997  960dc639-d199-4aae-a22e-18d4dfc07403       Automotive
# 99997     99998  f9897ea5-454f-43c2-a464-2de35502fe95      Electronics
# 99998     99999  17d6608f-5c4b-44da-a4ec-f3171120f7bb          Fashion
# 99999    100000  e6f4e3ae-a886-4da4-acbf-992019070b38             Toys
#
#        product_price  quantity  order_date         region payment_method  \
# ...

# %%
df.head()
# Out:
#    order_id                           customer_id product_category  \
# 0         1  bdd640fb-0667-4ad1-9c80-317fa3b1799d           Beauty
# 1         2  23b8c1e9-3924-46de-beb1-3b9046685257          Fashion
# 2         3  bd9c66b3-ad3c-4d6d-9a3d-1fa7bc8960a9           Beauty
# 3         4  972a8469-1641-4f82-8b9d-2434e465e150      Electronics
# 4         5  17fc695a-07a0-4a6e-8822-e8f36c031199          Fashion
#
#    product_price  quantity  order_date         region payment_method  \
# 0         190.40         5  2023-02-21         Europe   BankTransfer
# 1          82.22         3  2023-10-13  North America     CreditCard
# 2          15.19         2  2023-06-28        Oceania           Cash
# 3         310.65         2  2023-07-11         Europe         PayPal
# 4          74.05         4  2023-02-24         Africa         PayPal
#
#    delivery_days  is_returned  customer_rating  discount_percent  revenue
# ...

# %%
df.tail()
# Out:
#        order_id                           customer_id product_category  \
# 99995     99996  95898eb0-3712-4824-accb-8d40fab73167           Beauty
# 99996     99997  960dc639-d199-4aae-a22e-18d4dfc07403       Automotive
# 99997     99998  f9897ea5-454f-43c2-a464-2de35502fe95      Electronics
# 99998     99999  17d6608f-5c4b-44da-a4ec-f3171120f7bb          Fashion
# 99999    100000  e6f4e3ae-a886-4da4-acbf-992019070b38             Toys
#
#        product_price  quantity  order_date         region payment_method  \
# 99995         354.84         5  2025-07-21         Europe         PayPal
# 99996         168.49         2  2023-02-09  North America           Cash
# 99997         266.82         3  2023-06-13           Asia         PayPal
# 99998          36.09         1  2024-10-15  North America   BankTransfer
# 99999         174.20         2  2025-03-01           Asia   BankTransfer
#
#        delivery_days  is_returned  customer_rating  discount_percent  revenue
# ...

# %%
# check the shape of data
df.shape
# Out:
# (100000, 13)

# %%
# basic info
df.info
# Out:
# <bound method DataFrame.info of        order_id                           customer_id product_category  \
# 0             1  bdd640fb-0667-4ad1-9c80-317fa3b1799d           Beauty
# 1             2  23b8c1e9-3924-46de-beb1-3b9046685257          Fashion
# 2             3  bd9c66b3-ad3c-4d6d-9a3d-1fa7bc8960a9           Beauty
# 3             4  972a8469-1641-4f82-8b9d-2434e465e150      Electronics
# 4             5  17fc695a-07a0-4a6e-8822-e8f36c031199          Fashion
# ...         ...                                   ...              ...
# 99995     99996  95898eb0-3712-4824-accb-8d40fab73167           Beauty
# 99996     99997  960dc639-d199-4aae-a22e-18d4dfc07403       Automotive
# 99997     99998  f9897ea5-454f-43c2-a464-2de35502fe95      Electronics
# 99998     99999  17d6608f-5c4b-44da-a4ec-f3171120f7bb          Fashion
# 99999    100000  e6f4e3ae-a886-4da4-acbf-992019070b38             Toys
#
#        product_price  quantity  order_date         region payment_method  \
# ...

# %%
df.columns
# Out:
# Index(['order_id', 'customer_id', 'product_category', 'product_price',
#        'quantity', 'order_date', 'region', 'payment_method', 'delivery_days',
#        'is_returned', 'customer_rating', 'discount_percent', 'revenue'],
#       dtype='object')

# %%
# describe numerical column
df.describe()
# Out:
#             order_id  product_price       quantity  delivery_days  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean    50000.500000     250.962504       3.085480       4.984620
# std     28867.657797     141.743414       1.438706       2.579517
# min         1.000000       4.518000       1.000000       1.000000
# 25%     25000.750000     128.387500       2.000000       3.000000
# 50%     50000.500000     251.430000       3.000000       5.000000
# 75%     75000.250000     372.270000       4.000000       7.000000
# max    100000.000000     500.000000       6.000000       9.000000
#
#          is_returned  customer_rating  discount_percent        revenue
# count  100000.000000    100000.000000     100000.000000  100000.000000
# mean        0.060600         3.500493          5.014700     734.148001
# std         0.238596         0.867731          6.138865     571.191290
# min         0.000000         2.000000          0.000000       4.260000
# ...

# %% [markdown]
# ## cleaning data

# %%
# check missing value
df.isnull().sum()
# Out:
# order_id            0
# customer_id         0
# product_category    0
# product_price       0
# quantity            0
# order_date          0
# region              0
# payment_method      0
# delivery_days       0
# is_returned         0
# customer_rating     0
# discount_percent    0
# revenue             0
# dtype: int64

# %%
df = df.drop_duplicates() # remove duplicates if any 
df
# Out:
#        order_id                           customer_id product_category  \
# 0             1  bdd640fb-0667-4ad1-9c80-317fa3b1799d           Beauty
# 1             2  23b8c1e9-3924-46de-beb1-3b9046685257          Fashion
# 2             3  bd9c66b3-ad3c-4d6d-9a3d-1fa7bc8960a9           Beauty
# 3             4  972a8469-1641-4f82-8b9d-2434e465e150      Electronics
# 4             5  17fc695a-07a0-4a6e-8822-e8f36c031199          Fashion
# ...         ...                                   ...              ...
# 99995     99996  95898eb0-3712-4824-accb-8d40fab73167           Beauty
# 99996     99997  960dc639-d199-4aae-a22e-18d4dfc07403       Automotive
# 99997     99998  f9897ea5-454f-43c2-a464-2de35502fe95      Electronics
# 99998     99999  17d6608f-5c4b-44da-a4ec-f3171120f7bb          Fashion
# 99999    100000  e6f4e3ae-a886-4da4-acbf-992019070b38             Toys
#
#        product_price  quantity  order_date         region payment_method  \
# ...

# %%
# Saving cleaned dataset for further analysis
df.to_csv("cleaned_data.csv",index=False)

# %% [markdown]
# ## exploratory data analysis(eda)

# %% [markdown]
# ### univariate analysis (numerical columns)

# %%
num_cols = df.select_dtypes(include=['float64','int64']).columns

for col in num_cols:
    print(df[col].describe())
    sns.histplot(df[col], kde=True)
    plt.title(f"Distribution of {col}")
    plt.show()
# Out:
# count    100000.000000
# mean      50000.500000
# std       28867.657797
# min           1.000000
# 25%       25000.750000
# 50%       50000.500000
# 75%       75000.250000
# max      100000.000000
# Name: order_id, dtype: float64
# count    100000.000000
# mean        250.962504
# std         141.743414
# min           4.518000
# 25%         128.387500
# 50%         251.430000
# 75%         372.270000
# max         500.000000
# Name: product_price, dtype: float64
# count    100000.000000
# mean          3.085480
# std           1.438706
# min           1.000000
# 25%           2.000000
# 50%           3.000000
# 75%           4.000000
# max           6.000000
# Name: quantity, dtype: float64
# count    100000.000000
# mean          4.984620
# std           2.579517
# min           1.000000
# 25%           3.000000
# 50%           5.000000
# 75%           7.000000
# max           9.000000
# Name: delivery_days, dtype: float64
# count    100000.000000
# mean          0.060600
# ...

# %%
for col in num_cols: #outlier analysis
    sns.boxplot(df[col])
    plt.title(f"Outlier Analysis for {col}")
    plt.show()

# %%
# Univariate Analysis: Categorical Columns

cat_cols = df.select_dtypes(include=['object']).columns

for col in cat_cols:
    print(f"\n----- {col} -----")
    print(df[col].value_counts().head())  # show top 5 categories
    
    plt.figure(figsize=(8,4))
    sns.countplot(data=df, x=col, order=df[col].value_counts().index[:10])
    plt.title(f"Countplot of {col} (Top 10)")
    plt.xticks(rotation=45)
    plt.show()
# Out:
# ----- customer_id -----
# customer_id
# bdd640fb-0667-4ad1-9c80-317fa3b1799d    1
# 23b8c1e9-3924-46de-beb1-3b9046685257    1
# bd9c66b3-ad3c-4d6d-9a3d-1fa7bc8960a9    1
# 972a8469-1641-4f82-8b9d-2434e465e150    1
# 17fc695a-07a0-4a6e-8822-e8f36c031199    1
# Name: count, dtype: int64
# ----- product_category -----
# product_category
# Electronics    14375
# Sports         14354
# Fashion        14327
# Toys           14289
# Automotive     14239
# Name: count, dtype: int64
# ----- order_date -----
# order_date
# 2023-11-18    122
# 2025-05-21    119
# 2024-03-24    118
# 2023-10-13    118
# 2025-02-07    117
# Name: count, dtype: int64
# ----- region -----
# region
# Oceania          16965
# Asia             16763
# North America    16749
# South America    16560
# Europe           16513
# Name: count, dtype: int64
# ----- payment_method -----
# payment_method
# CreditCard      25222
# BankTransfer    25083
# PayPal          24985
# Cash            24710
# Name: count, dtype: int64

# %% [markdown]
# ### Bivariate Analysis

# %%
# Correlation Heatmap
plt.figure(figsize=(10,6))
sns.heatmap(df[num_cols].corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# ## Bivariate Analysis – Numeric vs Numeric

# %%
import matplotlib.pyplot as plt
import seaborn as sns

num_pairs = [
    ('product_price', 'revenue'),
    ('discount_percent', 'revenue'),
    ('quantity', 'revenue'),
    ('delivery_days', 'customer_rating')
]

plt.figure(figsize=(12,10))

for i, (x, y) in enumerate(num_pairs, 1):
    plt.subplot(2, 2, i)
    sns.scatterplot(data=df, x=x, y=y, alpha=0.4)
    plt.title(f"{x} vs {y}")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## MULTIVARIATE ANALYSIS

# %% [markdown]
# ### Revenue vs Discount across Product Categories

# %%
plt.figure(figsize=(10,6))
sns.boxplot(
    data=df,
    x='discount_percent',
    y='revenue',
    hue='product_category'
)
plt.title("Revenue vs Discount across Product Categories")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Revenue by Region & Quantity

# %%
plt.figure(figsize=(10,6))
sns.barplot(
    data=df,
    x='region',
    y='revenue',
    hue='quantity'
)
plt.title("Revenue by Region and Quantity")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Category × Region Revenue Heatmap

# %%
pivot = df.pivot_table(
    values='revenue',
    index='product_category',
    columns='region',
    aggfunc='mean'
)

plt.figure(figsize=(10,6))
sns.heatmap(pivot, annot=True, cmap='coolwarm')
plt.title("Average Revenue by Product Category and Region")
plt.show()
