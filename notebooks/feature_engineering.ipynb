# %% [markdown]
# ## FEATURE ENGINEERING

# %%
import os
os.getcwd()
# Out:
# 'e:\\Projects\\E-Commerce Revenue Optimization Engine\\notebooks'

# %%
os.listdir()
# Out:
# ['cleaned_data.csv',
#  'data_exploration.ipynb',
#  'feature_engineering.ipynb',
#  'forcasting_and_evaluation.ipynb',
#  'model_training.ipynb']

# %%
df = pd.read_csv("cleaned_data.csv")

# %% [markdown]
# ### Load cleaned data

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("cleaned_data.csv")
df['order_date'] = pd.to_datetime(df['order_date'])

# %% [markdown]
# ### Create Time-Based Features

# %%
df['year'] = df['order_date'].dt.year
df['month'] = df['order_date'].dt.month
df['week'] = df['order_date'].dt.isocalendar().week
df['day_of_week'] = df['order_date'].dt.dayofweek

# %% [markdown]
# ### Pricing & Discount Features

# %%
df['discounted_price'] = df['product_price'] * (1 - df['discount_percent']/100)
df['revenue_per_unit'] = df['revenue'] / df['quantity']

# %% [markdown]
# ### Demand Signal

# %%
df['daily_demand'] = df.groupby(
    ['product_category', 'order_date']
)['quantity'].transform('sum')

# %% [markdown]
# ### Save engineered data

# %%
# df.to_csv("notebooks/engineered_data.csv", index=False)
